# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Resources/DATA/Advertising.csv')

# %%
X = df.drop('sales', axis=1)

# %%
y = df.sales

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 7.341775789034128

# %%
model2 = Ridge(alpha=1)

# %%
model2.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred2 = model2.predict(X_test)

# %%
mean_squared_error(y_test, y_pred2)
# Out:
# 2.3190215794287514

# %% [markdown]
# # Train, Validation, Test Split

# %%
X = df.drop('sales', axis=1)
y = df.sales

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size =0.3, random_state=101)

# %%
X_validation, X_test, y_validation, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=101)

# %%
print(len(df), len(X_train), len(X_validation), len(X_test))
print(len(df), len(y_train), len(y_validation), len(y_test))
# Out:
# 200 140 30 30
# 200 140 30 30

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_validation = scaler.transform(X_validation)
X_test = scaler.transform(X_test)

# %%
model1 = Ridge(alpha=100)

# %%
model1.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_val_pred=model1.predict(X_validation)

# %%
mean_squared_error(y_validation, y_val_pred)
# Out:
# 7.320101458823869

# %%
model2 = Ridge(alpha=1)

# %%
model2.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_val_pred2=model2.predict(X_validation)

# %%
mean_squared_error(y_validation, y_val_pred2)
# Out:
# 2.3837830750569853

# %%
model3 = Ridge(alpha=5)

# %%
model3.fit(X_train, y_train)
# Out:
# Ridge(alpha=5)

# %%
y_val_pred3 = model3.predict(X_validation)

# %%
mean_squared_error(y_validation, y_val_pred3)
# Out:
# 2.5083200632605

# %%
y_test_pred = model2.predict(X_test)

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 2.254260083800517

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', 
                       cv=5)

# %%
score1
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(score1.mean())
# Out:
# 8.215396464543607

# %%
score2 = cross_val_score(model2, X_train, y_train, scoring='neg_mean_squared_error', cv =5)

# %%
score2
# Out:
# array([-3.15513238, -1.58086982, -5.40455562, -2.21654481, -4.36709384])

# %%
abs(score2.mean())
# Out:
# 3.344839296530695

# %%
model2.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model2.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.3190215794287514

# %% [markdown]
# # Cross Validate

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha=100)

# %%
score = cross_validate(model, X_train, y_train, 
                       scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error'],cv = 10)

# %%
score
# Out:
# {'fit_time': array([0.00500512, 0.0040009 , 0.00400186, 0.00399709, 0.00400138,
#         0.00499773, 0.00400209, 0.00400138, 0.0080061 , 0.00799894]),
#  'score_time': array([0.00299859, 0.00399995, 0.0059998 , 0.004004  , 0.00400066,
#         0.00300407, 0.01600051, 0.0109992 , 0.00600147, 0.00600052]),
#  'test_neg_mean_squared_error': array([ -6.06067062, -10.62703078,  -3.99342608,  -5.00949402,
#          -9.14179955, -13.08625636,  -3.83940454,  -9.05878567,
#          -9.05545685,  -5.77888211]),
#  'test_neg_mean_absolute_error': array([-1.8102116 , -2.54195751, -1.46959386, -1.86276886, -2.52069737,
#         -2.45999491, -1.45197069, -2.37739501, -2.44334397, -1.89979708])}

# %%
score = pd.DataFrame(score)

# %%
score.mean()
# Out:
# fit_time                        0.005001
# score_time                      0.006301
# test_neg_mean_squared_error    -7.565121
# test_neg_mean_absolute_error   -2.083773
# dtype: float64

# %%
model1 = Ridge(alpha=1)

# %%
score1 = cross_validate(model1, X_train, y_train, 
                       scoring = ['neg_mean_squared_error', 'neg_mean_absolute_error'],cv = 10)

# %%
score1 = pd.DataFrame(score1)

# %%
score1.mean()
# Out:
# fit_time                        0.005201
# score_time                      0.003503
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
model1.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model1.predict(X_test)

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 2.3190215794287514

# %% [markdown]
# # Grid Search CV

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet

# %%
base_en_model = ElasticNet()

# %%
param_grid = {'alpha':[0.1, 1, 5, 10, 50, 100], 
              'l1_ratio':[.1, .5, .7, .95, .99, 1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_en_model, 
                         param_grid = param_grid,
                         scoring = 'neg_mean_squared_error', 
                         cv = 5, 
                         verbose = 2)

# %%
grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.5s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# ...

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %%
results = grid_model.cv_results_
results = pd.DataFrame(results)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.115968      0.224935         0.001401        0.000490          0.1
# 1        0.003400      0.001356         0.001400        0.000488          0.1
# 2        0.002600      0.000490         0.001803        0.000750          0.1
# 3        0.002799      0.000750         0.001400        0.000488          0.1
# 4        0.002400      0.000490         0.001201        0.000400          0.1
# 5        0.005597      0.006210         0.001802        0.000749          0.1
# 6        0.002400      0.000491         0.001401        0.000490          1.0
# 7        0.002801      0.000749         0.001401        0.000490          1.0
# 8        0.003001      0.000634         0.001801        0.001167          1.0
# 9        0.007001      0.002001         0.002000        0.001267          1.0
# 10       0.003200      0.001167         0.001402        0.000489          1.0
# ...

# %%
y_pred = grid_model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.387342642087474
